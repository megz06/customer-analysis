# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"C:\Users\ELCOT\OneDrive\Desktop\my_fst_project\archive\Sample_ Superstore.csv",encoding='latin1')
print("Data Loaded!")
print("Shape",df.shape)
# Out:
# Data Loaded!
# Shape (9994, 19)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"C:\Users\ELCOT\OneDrive\Desktop\my_fst_project\archive\Sample_ Superstore.csv",encoding='latin1')
print("Customer Segment Analysis")
segment_sales=df.groupby("Segment")["Sales"].sum()
print(segment_sales)
print("\nRegion Analysis")
region_sales=df.groupby("Region")["Sales"].sum()
print(region_sales)
# Out:
# Customer Segment Analysis
# Segment
# Consumer       1.161401e+06
# Corporate      7.061464e+05
# Home Office    4.296531e+05
# Name: Sales, dtype: float64
#
# Region Analysis
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"C:\Users\ELCOT\OneDrive\Desktop\my_fst_project\archive\Sample_ Superstore.csv",encoding='latin1')
fig,(ax1,ax2)=plt.subplots(1,2, figsize=(12,5))
segment_sales.plot(kind="bar",ax=ax1, color=["blue","green","red"])
ax1.set_title("Sales by Segment")
region_sales.plot(kind="bar",ax=ax2, color=["purple","cyan","orange","pink"])
ax2.set_title("Sales by Region")
plt.tight_layout()
plt.savefig("customer_analysis.png")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"C:\Users\ELCOT\OneDrive\Desktop\my_fst_project\archive\Sample_ Superstore.csv",encoding='latin1')
top_customers=df.groupby("Customer ID")["Sales"].sum().sort_values(ascending=False).head(10)
print("Top 10 Customers by Sales")
print(top_customers)
top_customers.plot(kind="bar",color="teal")
plt.title("Top 10 Customers")
plt.xlabel("Customer ID")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("top_customers.png")
plt.show()
# Out:
# Top 10 Customers by Sales
# Customer ID
# SM-20320    25043.050
# TC-20980    19052.218
# RB-19360    15117.339
# TA-21385    14595.620
# AB-10105    14473.571
# KL-16645    14175.229
# SC-20095    14142.334
# HL-15040    12873.298
# SE-20110    12209.438
# CC-12370    12129.072
# Name: Sales, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv(r"C:\Users\ELCOT\OneDrive\Desktop\my_fst_project\archive\Sample_ Superstore.csv",encoding='latin1')
print("KEY CUSTOMER INSIGHTS")
print("=======================")
print("1. Consumer segment has highest sales")
print("2. West region is the strongest market")
print("3. South region has lowest sales")
print("4. Top 10 customers drive significant revenue")
